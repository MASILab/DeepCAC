# %%
import os
import pandas as pd 
from tqdm import tqdm
import shutil

table_real = pd.read_csv('/nfs2/NLST/NIfTI/T0_all.csv')

# %%
table = table_real.loc[table_real['nii_file'] == 1]

# %%
table.loc[table['convolution_kernel'] == 'B50f']
#pid113222:Siemens B30f soft kernel
#pid214564:Philips C soft kernel
#pid202950:Toshiba FC10 soft kernel
#pid130700:Siemens B50f kernel
#pid101009:Toshiba FC51 hard kernel
# Out:
#           pid manufacture   model_name convolution_kernel  slice_thickness  \
# 13     113222     SIEMENS  Volume Zoom               B50f              2.0
# 21     130700     SIEMENS  Volume Zoom               B50f              2.0
# 24     119105     SIEMENS  Volume Zoom               B50f              2.0
# 28     119105     SIEMENS  Volume Zoom               B50f              5.0
# 34     117010     SIEMENS  Volume Zoom               B50f              2.0
# ...       ...         ...          ...                ...              ...
# 69864  131938     SIEMENS  Volume Zoom               B50f              2.0
# 69868  110703     SIEMENS  Volume Zoom               B50f              2.0
# 69873  116391     SIEMENS  Volume Zoom               B50f              2.0
# 69877  116391     SIEMENS  Volume Zoom               B50f              5.0
# 69878  118284     SIEMENS  Volume Zoom               B50f              2.0
#
#        nii_file  png_file  voxel_size_x  voxel_size_y  voxel_size_z  \
# 13            1         1      0.742188      0.742188      2.000000
# 21            1         1      0.585938      0.585938      1.800000
# 24            1         1      0.820312      0.820312      2.000000
# 28            1         1      0.812500      0.812500      5.000000
# 34            1         1      0.585938      0.585938      2.000000
# ...         ...       ...           ...           ...           ...
# 69864         1         1      0.585938      0.585938      1.799999
# 69868         1         1      0.625000      0.625000      2.000000
# 69873         1         1      0.669922      0.669922      2.000000
# 69877         1         1      0.687500      0.687500      5.000000
# 69878         1         1      0.625000      0.625000      1.799999
#
#        num_img_dimension  num_dcm orient  \
# 13                   3.0      152    LAS
# 21                   3.0      174    LAS
# 24                   3.0      156    LAS
# 28                   3.0       62    LAS
# 34                   3.0      138    LAS
# ...                  ...      ...    ...
# 69864                3.0      173    LAS
# 69868                3.0      152    LAS
# 69873                3.0      168    LAS
# 69877                3.0       67    LAS
# 69878                3.0      181    LAS
#
#                                               series_uid  \
# 13     1.2.840.113654.2.55.70350566232973584386767442...
# 21     1.2.840.113654.2.55.25191845727486983905962799...
# 24     1.2.840.113654.2.55.33206632310736693719441091...
# 28     1.2.840.113654.2.55.12229684244352406037307625...
# 34     1.2.840.113654.2.55.11874677972414968422433841...
# ...                                                  ...
# 69864  1.2.840.113654.2.55.66301509501284720029665557...
# 69868  1.2.840.113654.2.55.12548391059204018897520606...
# 69873  1.2.840.113654.2.55.32509128345160602390535636...
# 69877  1.2.840.113654.2.55.29229590028334790421971244...
# 69878  1.2.840.113654.2.55.37466128540046747330702146...
#
#        record_retrieval_failed time_point
# 13                         NaN         T0
# 21                         NaN         T0
# 24                         NaN         T0
# 28                         NaN         T0
# 34                         NaN         T0
# ...                        ...        ...
# 69864                      NaN         T0
# 69868                      NaN         T0
# 69873                      NaN         T0
# 69877                      NaN         T0
# 69878                      NaN         T0
#
# [8472 rows x 16 columns]

# %%
pids= ["113222_B30f", "214564_C", "202950_FC10", "130700_B50f", "101009_FC51"]
test_path = '/home-local/DeepCAC/test_data'
for id in pids:
    dirs = os.path.join(test_path, id)
    os.mkdir(dirs)

# %% [markdown]
# ## Paths are created, pull image pids and the series uid and obtain the data from the directory.

# %%
img_dir = '/nfs2/NLST/NIfTI/T0_all'

# %%
pid= [113222, 214564, 202950, 130700, 101009]
kern = ["B30f", "C", "FC10", "B50f", "FC51"]
#print(table.loc[(table['pid'] == pid[0]) & (table['convolution_kernel'] == 'B30f')])
for id in range(len(pid)):
    val = table.loc[(table['pid'] == pid[id]) & (table['convolution_kernel'] == kern[id])]
    print(val['series_uid'])
# Out:
# 10    1.2.840.113654.2.55.44013695086494030958098622...
# 12    1.2.840.113654.2.55.24271668811235036636385070...
# Name: series_uid, dtype: object
# 22    1.3.6.1.4.1.14519.5.2.1.7009.9004.304061800794...
# Name: series_uid, dtype: object
# 35    1.3.6.1.4.1.14519.5.2.1.7009.9004.216924991745...
# Name: series_uid, dtype: object
# 21    1.2.840.113654.2.55.25191845727486983905962799...
# Name: series_uid, dtype: object
# 66    1.2.840.113654.2.55.17237409873764955972081933...
# Name: series_uid, dtype: object

# %% [markdown]
# ## Creating data directories to run CAC pipeline on B30f_B50f (Hard to soft) conversion

# %%
#data_path = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/hard/raw/ct'
#data_path = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/soft/raw/ct'
data_path = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/test_scan_converted'

# %%
for file in os.listdir(data_path):
    print(file)
    fold_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'
    pid = os.path.join(fold_pth, file.split('.')[0])
    #print(pid)
    os.mkdir(pid)
# Out:
# 214801.nii.gz
# 120870.nii.gz
# 127237.nii.gz
# 131491.nii.gz
# 116037.nii.gz
# 117593.nii.gz
# 204318.nii.gz
# 122259.nii.gz
# 130733.nii.gz
# 129565.nii.gz
# 125450.nii.gz
# 115322.nii.gz
# 122683.nii.gz
# 129382.nii.gz
# 132539.nii.gz
# 134447.nii.gz
# 121296.nii.gz
# 124995.nii.gz
# 207023.nii.gz
# 213098.nii.gz
# 114213.nii.gz
# 105528.nii.gz
# 116127.nii.gz
# 215911.nii.gz
# 119557.nii.gz
# 209253.nii.gz
# 110844.nii.gz
# 131418.nii.gz
# 127482.nii.gz
# 121020.nii.gz
# 103093.nii.gz
# 115307.nii.gz
# 108246.nii.gz
# 112305.nii.gz
# 112276.nii.gz
# 130692.nii.gz
# 108074.nii.gz
# 121945.nii.gz
# 113767.nii.gz
# 131882.nii.gz
# 114712.nii.gz
# 132109.nii.gz
# 109648.nii.gz
# 133481.nii.gz
# 104934.nii.gz
# 203215.nii.gz
# 123546.nii.gz
# 108529.nii.gz
# 131074.nii.gz
# 103954.nii.gz
# 131908.nii.gz
# 120125.nii.gz
# 200134.nii.gz
# 128935.nii.gz
# 114751.nii.gz
# 210806.nii.gz
# 128831.nii.gz
# 213330.nii.gz
# 118499.nii.gz
# 127566.nii.gz
# 123754.nii.gz
# 106659.nii.gz
# 216746.nii.gz
# 203730.nii.gz
# 110615.nii.gz
# 121082.nii.gz
# 129534.nii.gz
# 119703.nii.gz
# 205832.nii.gz
# 130573.nii.gz
# 120649.nii.gz
# 114676.nii.gz
# 123082.nii.gz
# 125247.nii.gz
# 203688.nii.gz
# 113356.nii.gz
# 103109.nii.gz
# 128882.nii.gz
# 109935.nii.gz
# 107507.nii.gz
# 125733.nii.gz
# 109731.nii.gz
# 115743.nii.gz
# 134263.nii.gz
# 126709.nii.gz
# 204170.nii.gz
# 119998.nii.gz
# 130069.nii.gz
# 109353.nii.gz
# 131064.nii.gz
# 207645.nii.gz
# 119540.nii.gz
# 117340.nii.gz
# 109491.nii.gz
# 114423.nii.gz
# 113188.nii.gz
# 107569.nii.gz
# 118235.nii.gz
# 122411.nii.gz
# 101949.nii.gz

# %%
#Hard kernel
fold_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/hard/raw/'
for subdir,dir,files in os.walk(fold_pth):
    for file in files:
        orig = os.path.join(subdir,file)
        #print(orig)
        rename = os.path.join(subdir,'img.nii.gz')
        os.rename(orig,rename)

# %%
#soft kernel image directory creation
img_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/soft/raw/ct/'
for file in os.listdir(img_pth):
    org_path = img_pth+file
    for img_dir in os.listdir(fold_pth):
         if file.split('.')[0] == img_dir:
             copy_path = os.path.join(fold_pth,img_dir)
             #print(copy_path)
             shutil.copy(org_path,copy_path)
             #ren = os.path.join(fold_pth,img_dir,'img.nii.gz')

# %%
#renaming soft kernel images
impth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/soft/raw/'
for dir,subdir,files in os.walk(impth):
    for file in files:
        orig = os.path.join(dir,file)
        rename = os.path.join(dir,'img.nii.gz')
        os.rename(orig,rename)

# %%
#Converted kernel image
img_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/test_scan_converted/'
fold_pth = fold_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'
for file in os.listdir(img_pth):
    org_path = img_pth+file
    #print(org_path)
    for img_dir in os.listdir(fold_pth):
         if file.split('.')[0] == img_dir:
             copy_path = os.path.join(fold_pth,img_dir)
             #print(copy_path)
             shutil.copy(org_path,copy_path)

# %%
#renaming converted images
impth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'
for dir,subdir,files in os.walk(impth):
    for file in files:
        orig = os.path.join(dir,file)
        rename = os.path.join(dir,'img.nii.gz')
        os.rename(orig,rename)
