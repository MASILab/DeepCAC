# %%
import os
import pandas as pd 
from tqdm import tqdm
import shutil

# %% [markdown]
# ## Creating data directories to run CAC pipeline on B30f_B50f (Hard to soft) conversion and soft to hard

# %%
#data_path = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/hard/raw/ct'
#data_path = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/soft/raw/ct'
#data_path = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/test_scan_converted'
data_path = '/nfs/Kernel_conversion_outputs/SIE_softtohard/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'

# %%
for file in os.listdir(data_path):
    print(file)
    fold_pth = '/nfs/Kernel_conversion_outputs/SIE_softtohard/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'
    pid = os.path.join(fold_pth, file.split('.')[0])
    #print(pid)
    os.mkdir(pid)
# Out:
# 132109.nii.gz
# 109648.nii.gz
# 114712.nii.gz
# 113767.nii.gz
# 131882.nii.gz
# 121945.nii.gz
# 108074.nii.gz
# 123546.nii.gz
# 203215.nii.gz
# 104934.nii.gz
# 133481.nii.gz
# 108246.nii.gz
# 103093.nii.gz
# 115307.nii.gz
# 127482.nii.gz
# 121020.nii.gz
# 110844.nii.gz
# 131418.nii.gz
# 209253.nii.gz
# 130692.nii.gz
# 112305.nii.gz
# 112276.nii.gz
# 124995.nii.gz
# 121296.nii.gz
# 134447.nii.gz
# 215911.nii.gz
# 119557.nii.gz
# 116127.nii.gz
# 105528.nii.gz
# 114213.nii.gz
# 213098.nii.gz
# 207023.nii.gz
# 117593.nii.gz
# 116037.nii.gz
# 131491.nii.gz
# 127237.nii.gz
# 214801.nii.gz
# 120870.nii.gz
# 132539.nii.gz
# 129382.nii.gz
# 115322.nii.gz
# 122683.nii.gz
# 130733.nii.gz
# 129565.nii.gz
# 125450.nii.gz
# 204318.nii.gz
# 122259.nii.gz
# 114423.nii.gz
# 109491.nii.gz
# 117340.nii.gz
# 207645.nii.gz
# 119540.nii.gz
# 109353.nii.gz
# 131064.nii.gz
# 130069.nii.gz
# 204170.nii.gz
# 119998.nii.gz
# 101949.nii.gz
# 122411.nii.gz
# 118235.nii.gz
# 107569.nii.gz
# 113188.nii.gz
# ...

# %%
#Hard kernel
fold_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/hard/raw/'
for subdir,dir,files in os.walk(fold_pth):
    for file in files:
        orig = os.path.join(subdir,file)
        #print(orig)
        rename = os.path.join(subdir,'img.nii.gz')
        os.rename(orig,rename)

# %%
#soft kernel image directory creation
img_pth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/soft/raw/ct/'
for file in os.listdir(img_pth):
    org_path = img_pth+file
    for img_dir in os.listdir(fold_pth):
         if file.split('.')[0] == img_dir:
             copy_path = os.path.join(fold_pth,img_dir)
             #print(copy_path)
             shutil.copy(org_path,copy_path)
             #ren = os.path.join(fold_pth,img_dir,'img.nii.gz')

# %%
#renaming soft kernel images
impth = '/nfs/Kernel_conversion_outputs/SIE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/soft/raw/'
for dir,subdir,files in os.walk(impth):
    for file in files:
        orig = os.path.join(dir,file)
        rename = os.path.join(dir,'img.nii.gz')
        os.rename(orig,rename)

# %%
#Converted kernel image
img_pth = '/nfs/Kernel_conversion_outputs/SIE_softtohard/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/convert/'
fold_pth = fold_pth = '/nfs/Kernel_conversion_outputs/SIE_softtohard/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'
for file in os.listdir(img_pth):
    org_path = img_pth+file
    #print(org_path)
    for img_dir in os.listdir(fold_pth):
         if file.split('.')[0] == img_dir:
             copy_path = os.path.join(fold_pth,img_dir)
             print(copy_path)
             shutil.copy(org_path,copy_path)

# %%
#renaming converted images
impth = '/nfs/Kernel_conversion_outputs/SIE_softtohard/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac/converted/raw/'
for dir,subdir,files in os.walk(impth):
    for file in files:
        orig = os.path.join(dir,file)
        rename = os.path.join(dir,'img.nii.gz')
        os.rename(orig,rename)

# %%
proj_root = '/nfs/Kernel_conversion_outputs'

all_kernels = [
    {'relative_dir': 'C_D_hardtosoft_2/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac'}, #completed
    {'relative_dir': 'C_D_softtohard/train_output/run_4/assessment_single_checkpoint/checkpoint_120/cac'},
    {'relative_dir': 'TOSH_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac'},
    {'relative_dir': 'TOSH_softtohard/train_output/run_5/assessment_single_checkpoint/checkpoint_120/cac'},
    {'relative_dir': 'GE_BONE_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac'}, 
    {'relative_dir': 'GE_BONE_softtohard/train_output/run_1/assessment_single_checkpoint/checkpoint_120/cac'}, 
    {'relative_dir': 'GE_LUNG_hardtosoft/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac'},
    {'relative_dir': 'GE_LUNG_softtohard/train_output/run_0/assessment_single_checkpoint/checkpoint_120/cac'}
]

kerns = ['hard', 'soft']
conv = "converted"
dat_hs = "ct"
dat_conv = "test_scan_converted"

all_kern = ["hard","soft", "converted"]

for all in all_kernels:
        path = os.path.join(proj_root, all['relative_dir'], conv, 'raw')
        for dir in os.listdir(path):
            if dir == 'test_scan_converted':
                print(os.path.join(path,dir), "Exists")
            else:
                print("No such directory")
# Out:
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# No such directory
# ...
